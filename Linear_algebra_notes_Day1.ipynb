# %% [markdown]
# <a href="https://colab.research.google.com/github/gs1charancharan/masai/blob/main/Linear_algebra_notes_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#identify Oranges from Tangerine
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/030/385/original/fruits.csv?1680749521 -O fruits.csv
# Out:
# --2025-11-13 15:51:24--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/030/385/original/fruits.csv?1680749521
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.65.227.110, 18.65.227.27, 18.65.227.25, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.65.227.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219 [text/plain]
# Saving to: ‘fruits.csv’
#
# fruits.csv          100%[===================>]     219  --.-KB/s    in 0s
#
# 2025-11-13 15:51:25 (72.1 MB/s) - ‘fruits.csv’ saved [219/219]

# %%
import pandas as pd
df = pd.read_csv('fruits.csv')
df.head(10)
# Out:
#    weight  diameter   color       fruit
# 0     4.0       3.0  orange  trangerine
# 1     4.2       4.0  orange  trangerine
# 2     3.8       3.5  orange  trangerine
# 3     4.5       3.8  orange  trangerine
# 4     2.8       5.0  orange      orange
# 5     2.5       5.2  orange      orange
# 6     2.7       5.3  orange      orange
# 7     3.2       4.5  orange      orange

# %%
import seaborn as sns
sns.scatterplot(x='weight', y = 'diameter', hue='fruit', data=df)
# Out:
# <Axes: xlabel='weight', ylabel='diameter'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive

def plot_line(m, c):
    x = np.linspace(2, 5, num=100)  # generate x values
    y = m*x + c  # calculate y values
    # plt.plot(x, y)  # plot the line
    sns.scatterplot(x='weight', y = 'diameter', hue='fruit', data=df)
    plt.plot(x, y)  # plot the line
    # plt.ylim(-50, 50)  # set y-axis limits
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'y = {m}x + {c}')
    plt.show()

interactive_plot = interactive(plot_line, m=(-1, 5, 0.1), c=(-5, 5, 1))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=2.0, description='m', max=5.0, min=-1.0), IntSlider(value=0, descripti…

# %%
import numpy as np

a = [1,2]
b = [5,7]

# %%
# %time a[0]*b[0] + a[1]*b[1]
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 7.87 µs
# 19

# %%
dot_product = 0
for i,j in zip(a,b):
  print(i, j)
  dot_product += i*j
dot_product
# Out:
# 1 5
# 2 7
# 19

# %%
# %time np.dot(a,b)
# Out:
# CPU times: user 53 µs, sys: 6 µs, total: 59 µs
# Wall time: 61.5 µs
# np.int64(19)

# %%
#plot a unit vector => mag = 1

import matplotlib.pyplot as plt
v = np.array([-2, 5])

unit_v = v / np.linalg.norm(v)

# Plot the vector starting from origin (0,0)
plt.figure()
plt.quiver(0, 0, unit_v[0], unit_v[1], angles='xy', scale_units='xy', scale=1, color='r')

# Set limits for better visualization
plt.xlim(-1, 1.5)
plt.ylim(-1, 1.5)

# Add grid and labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Unit Vector Visualization')

plt.show()
